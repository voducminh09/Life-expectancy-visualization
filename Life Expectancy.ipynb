# %%
# This sets plot images to a nice size
options(repr.plot.width = 6, repr.plot.height = 6)

# Loading packages
library(dplyr)
library(tidyr)
library(ggplot2)

# Loading data
life_expectancy <- read.csv("UNdata.csv")

# Taking a look at the first few rows
head(life_expectancy)
# Out:
#   Country.or.Area Subgroup Year
# 1 Afghanistan     Female   2000-2005
# 2 Afghanistan     Female   1995-2000
# 3 Afghanistan     Female   1990-1995
# 4 Afghanistan     Female   1985-1990
# 5 Afghanistan     Male     2000-2005
# 6 Afghanistan     Male     1995-2000
#   Source                                                        Unit  Value
# 1 UNPD_World Population Prospects_2006 (International estimate) Years 42
# 2 UNPD_World Population Prospects_2006 (International estimate) Years 42
# 3 UNPD_World Population Prospects_2006 (International estimate) Years 42
# 4 UNPD_World Population Prospects_2006 (International estimate) Years 41
# 5 UNPD_World Population Prospects_2006 (International estimate) Years 42
# 6 UNPD_World Population Prospects_2006 (International estimate) Years 42
#   Value.Footnotes
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
summary(life_expectancy)
# Out:
#     Country.or.Area
#  Afghanistan:   8
#  Albania    :   8
#  Algeria    :   8
#  Angola     :   8
#  Argentina  :   8
#  Armenia    :   8
#  (Other)    :1523
#                                                                                                                             Subgroup
#  Female                                                                                                                         :780
#  Male                                                                                                                           :780
#  As of 1 July 1997, Hong Kong became a Special Administrative Region (SAR) of China.                                            :  1
#  As of 20 December 1999, Macao became a Special Administrative Region (SAR) of China.                                           :  1
#  Footnote                                                                                                                       :  1
# ...

# %%
# Subsetting and reshaping the life expectancy data (2000-2005)
subdata_a <- life_expectancy  %>%
    filter(Year=="2000-2005") %>%
    select(Country.or.Area, Subgroup, Value) %>%
    spread(Subgroup, Value)

# Taking a look at the first few rows
head(subdata_a)
# Out:
#   Country.or.Area Female Male
# 1 Afghanistan     42     42
# 2 Albania         79     73
# 3 Algeria         72     70
# 4 Angola          43     39
# 5 Argentina       78     71
# 6 Armenia         75     68

# %%
#Exploring the data
ggplot(subdata_a, aes(x=Female))+geom_histogram(bins=30)+ggtitle("Female",subtitle ="Year: 2000-2005")+scale_x_continuous(limits = c(30, 90))
# Out:
# Warning message:
# "Removed 1 rows containing missing values (geom_bar)."
# plot without title

# %%
ggplot(subdata_a, aes(x=Male))+geom_histogram(bins=30)+ggtitle("Male",subtitle="Year: 2000-2005")+scale_x_continuous(limits = c(30, 90))
# Out:
# Warning message:
# "Removed 1 rows containing missing values (geom_bar)."
# plot without title

# %%
# Subseting data to obtain countries with largest difference between Male-Female and Female-Male life expectancy
top_male <- subdata_a %>% arrange(Male-Female) %>% head(3)
top_female <- subdata_a %>% arrange(Female-Male) %>% head(3)

# Adding text to the previous plot to label countries of interest 
ggplot(subdata_a, aes(x=Male, y=Female, label=Country.or.Area))+
  geom_point(colour="white", fill="orange", shape=21, alpha=.55, size=5)+
  geom_abline(intercept = 0, slope = 1, linetype=2)+
  scale_x_continuous(limits=c(35,85))+
  scale_y_continuous(limits=c(35,85))+
  labs(title="Life Expectancy at Birth by Country",
       subtitle="Years. Period: 2000-2005. Average.",
       caption="Source: United Nations Statistics Division",
       x="Males",
       y="Females")+
  geom_text(data=top_male, size=3,color="green")+
  geom_text(data=top_female, size=3,color="red")+
theme_bw()
# Out:
# plot without title

# %%
# Subsetting and reshaping the life expectancy data (1995-2000)
subdata_b <- life_expectancy  %>%
    filter(Year=="1995-2000") %>%
    select(Country.or.Area, Subgroup, Value) %>%
    spread(Subgroup, Value)

# Taking a look at the first few rows
head(subdata_b)
# Out:
#   Country.or.Area Female Male
# 1 Afghanistan     42     42
# 2 Albania         76     70
# 3 Algeria         70     68
# 4 Angola          43     39
# 5 Argentina       77     70
# 6 Armenia         74     67

# %%
#Exploring the data
ggplot(subdata_b, aes(x=Female))+geom_histogram(bins=30)+ggtitle("Female",subtitle ="Year: 1995-2000")+scale_x_continuous(limits = c(30, 90))
# Out:
# Warning message:
# "Removed 1 rows containing missing values (geom_bar)."
# plot without title

# %%
ggplot(subdata_b, aes(x=Male))+geom_histogram(bins=30)+ggtitle("Male",subtitle ="Year: 1995-2000")+scale_x_continuous(limits = c(30, 90))
# Out:
# Warning message:
# "Removed 1 rows containing missing values (geom_bar)."
# plot without title

# %%
# Subseting data to obtain countries with largest difference between Male-Female and Female-Male life expectancy
top_male <- subdata_b %>% arrange(Male-Female) %>% head(3)
top_female <- subdata_b %>% arrange(Female-Male) %>% head(3)

# Adding text to the previous plot to label countries of interest 
ggplot(subdata_b, aes(x=Male, y=Female, label=Country.or.Area))+
  geom_point(colour="white", fill="yellow", shape=21, alpha=.55, size=5)+
  geom_abline(intercept = 0, slope = 1, linetype=2)+
  scale_x_continuous(limits=c(35,85))+
  scale_y_continuous(limits=c(35,85))+
  labs(title="Life Expectancy at Birth by Country",
       subtitle="Years. Period: 1995-2000. Average.",
       caption="Source: United Nations Statistics Division",
       x="Males",
       y="Females")+
  geom_text(data=top_male, size=3,color="green")+
  geom_text(data=top_female, size=3,color="red")+
theme_bw()
# Out:
# Warning message:
# "Removed 1 rows containing missing values (geom_point)."
# plot without title

# %%
# Subsetting and reshaping the life expectancy data (1990-1995)
subdata_c <- life_expectancy  %>%
    filter(Year=="1990-1995") %>%
    select(Country.or.Area, Subgroup, Value) %>%
    spread(Subgroup, Value)

# Taking a look at the first few rows
head(subdata_c)
# Out:
#   Country.or.Area Female Male
# 1 Afghanistan     42     42
# 2 Albania         75     69
# 3 Algeria         69     67
# 4 Angola          42     39
# 5 Argentina       76     69
# 6 Armenia         72     65

# %%
#Exploring the data
ggplot(subdata_c, aes(x=Female))+geom_histogram(bins=30)+ggtitle("Female",subtitle ="Year: 1990-1995")+scale_x_continuous(limits = c(30, 90))
# Out:
# Warning message:
# "Removed 1 rows containing non-finite values (stat_bin)."Warning message:
# "Removed 1 rows containing missing values (geom_bar)."
# plot without title

# %%
ggplot(subdata_c, aes(x=Male))+geom_histogram(bins=30)+ggtitle("Male",subtitle ="Year: 1990-1995")+scale_x_continuous(limits = c(30, 90))
# Out:
# Warning message:
# "Removed 1 rows containing non-finite values (stat_bin)."Warning message:
# "Removed 1 rows containing missing values (geom_bar)."
# plot without title

# %%
# Subseting data to obtain countries with largest difference between Male-Female and Female-Male life expectancy
top_male <- subdata_c %>% arrange(Male-Female) %>% head(3)
top_female <- subdata_c %>% arrange(Female-Male) %>% head(3)

# Adding text to the previous plot to label countries of interest 
ggplot(subdata_c, aes(x=Male, y=Female, label=Country.or.Area))+
  geom_point(colour="white", fill="blue", shape=21, alpha=.55, size=5)+
  geom_abline(intercept = 0, slope = 1, linetype=2)+
  scale_x_continuous(limits=c(35,85))+
  scale_y_continuous(limits=c(35,85))+
  labs(title="Life Expectancy at Birth by Country",
       subtitle="Years. Period: 1990-1995. Average.",
       caption="Source: United Nations Statistics Division",
       x="Males",
       y="Females")+
  geom_text(data=top_male, size=3,color="green")+
  geom_text(data=top_female, size=3,color="red")+
theme_bw()
# Out:
# Warning message:
# "Removed 1 rows containing missing values (geom_point)."
# plot without title

# %%
# Subsetting and reshaping the life expectancy data (1985-1990)
subdata_d <- life_expectancy  %>%
    filter(Year=="1985-1990") %>%
    select(Country.or.Area, Subgroup, Value) %>%
    spread(Subgroup, Value)

# Taking a look at the first few rows
head(subdata_d)
# Out:
#   Country.or.Area Female Male
# 1 Afghanistan     41     41
# 2 Albania         75     69
# 3 Algeria         67     65
# 4 Angola          42     38
# 5 Argentina       75     68
# 6 Armenia         71     66

# %%
#Exploring the data
ggplot(subdata_d, aes(x=Female))+geom_histogram(bins=30)+ggtitle("Female",subtitle ="Year: 1985-1990")+scale_x_continuous(limits = c(30, 90))
# Out:
# Warning message:
# "Removed 1 rows containing missing values (geom_bar)."
# plot without title

# %%
ggplot(subdata_d, aes(x=Male))+geom_histogram(bins=30)+ggtitle("Male",subtitle ="Year: 1985-1990")+scale_x_continuous(limits = c(30, 90))
# Out:
# Warning message:
# "Removed 1 rows containing missing values (geom_bar)."
# plot without title

# %%
# Subseting data to obtain countries with largest difference between Male-Female and Female-Male life expectancy
top_male <- subdata_d %>% arrange(Male-Female) %>% head(3)
top_female <- subdata_d %>% arrange(Female-Male) %>% head(3)

# Adding text to the previous plot to label countries of interest 
ggplot(subdata_d, aes(x=Male, y=Female, label=Country.or.Area))+
  geom_point(colour="white", fill="purple", shape=21, alpha=.55, size=5)+
  geom_abline(intercept = 0, slope = 1, linetype=2)+
  scale_x_continuous(limits=c(35,85))+
  scale_y_continuous(limits=c(35,85))+
  labs(title="Life Expectancy at Birth by Country",
       subtitle="Years. Period: 1985-1990. Average.",
       caption="Source: United Nations Statistics Division",
       x="Males",
       y="Females")+
  geom_text(data=top_male, size=3,color="green")+
  geom_text(data=top_female, size=3,color="red")+
theme_bw()
# Out:
# plot without title

# %%
# Subsetting, mutating and reshaping the life expectancy data to see how life expectancy changes
subdata2 <- life_expectancy %>% 
  filter(Year %in% c("1985-1990", "2000-2005")) %>% 
  mutate(Sub_Year=paste(Subgroup, Year, sep="_")) %>% 
  mutate(Sub_Year=gsub("-", "_", Sub_Year)) %>% 
  select(-Subgroup, -Year) %>% 
  spread(Sub_Year, Value) %>% 
  mutate(diff_Female = Female_2000_2005 - Female_1985_1990, 
         diff_Male   = Male_2000_2005 - Male_1985_1990)

# Taking a look at the first few rows
head(subdata2)
# Out:
#   Country.or.Area Source
# 1 Afghanistan     UNPD_World Population Prospects_2006 (International estimate)
# 2 Albania         UNPD_World Population Prospects_2006 (International estimate)
# 3 Algeria         UNPD_World Population Prospects_2006 (International estimate)
# 4 Angola          UNPD_World Population Prospects_2006 (International estimate)
# 5 Argentina       UNPD_World Population Prospects_2006 (International estimate)
# 6 Armenia         UNPD_World Population Prospects_2006 (International estimate)
#   Unit  Value.Footnotes Female_1985_1990 Female_2000_2005 Male_1985_1990
# 1 Years NA              41               42               41
# 2 Years NA              75               79               69
# 3 Years NA              67               72               65
# 4 Years NA              42               43               38
# 5 Years NA              75               78               68
# 6 Years NA              71               75               66
# ...

# %%
summary(subdata2)
# Out:
#     Country.or.Area
#  Afghanistan:  1
#  Albania    :  1
#  Algeria    :  1
#  Angola     :  1
#  Argentina  :  1
#  Armenia    :  1
#  (Other)    :189
#                                                            Source
#                                                               :  0
#  UNPD_World Population Prospects_2006 (International estimate):195
#
#
#
#
#
#     Unit     Value.Footnotes Female_1985_1990 Female_2000_2005 Male_1985_1990
#       :  0   Min.   : 1.00   Min.   :41.0     Min.   :39.00    Min.   :38.00
#  Years:195   1st Qu.: 3.25   1st Qu.:59.0     1st Qu.:62.50    1st Qu.:56.00
#              Median : 5.50   Median :70.0     Median :74.00    Median :65.00
#              Mean   : 5.50   Mean   :66.9     Mean   :69.43    Mean   :62.07
#              3rd Qu.: 7.75   3rd Qu.:75.0     3rd Qu.:79.00    3rd Qu.:69.00
#              Max.   :10.00   Max.   :81.0     Max.   :85.00    Max.   :76.00
#              NA's   :185
# ...

# %%
# Subseting data to obtain countries of interest
top <- subdata2 %>% arrange(diff_Male+diff_Female) %>% head(3)
bottom <- subdata2 %>% arrange(-(diff_Male+diff_Female)) %>% head(3)

# Adding text to the previous plot to label countries of interest
ggplot(subdata2, aes(x=diff_Male, y=diff_Female, label=Country.or.Area), guide=FALSE)+
  geom_point(colour="white", fill="brown", shape=21, alpha=.55, size=5)+
  geom_abline(intercept = 0, slope = 1, linetype=2)+
  scale_x_continuous(limits=c(-25,25))+
  scale_y_continuous(limits=c(-25,25))+
  geom_hline(yintercept=0, linetype=2)+
  geom_vline(xintercept=0, linetype=2)+
  labs(title="Life Expectancy at Birth by Country",
       subtitle="Years. Difference between 1985-1990 and 2000-2005. Average.",
       caption="Source: United Nations Statistics Division",
       x="Males",
       y="Females")+
  geom_text(data=top, size=3,color="red")+
  geom_text(data=bottom, size=3,color="green")+
  theme_bw()
# Out:
# plot without title
